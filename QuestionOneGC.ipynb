# %%
import pandas as pd

# %%
from google.colab import files
data_to_load = files.upload()
# Out:
#      <input type="file" id="files-5206fc36-31dd-4c77-b4b2-cfe107139934" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5206fc36-31dd-4c77-b4b2-cfe107139934">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Article-Devices.csv to Article-Devices (1).csv

# %%
import io
df = pd.read_csv(io.BytesIO(data_to_load['Article-Devices.csv']))

# %%
data = pd.read_csv ('Article-Devices.csv')

# %%
mobile=data ['Mobile'].sum()
print (mobile)
# Out:
# 1036442

# %%
tablet=data ['Tablet'].sum()
print (tablet)
# Out:
# 131084

# %%
total=data ['Total'].sum()
print (total)
# Out:
# 1435985

# %%
((mobile+tablet)/total)*100
# Out:
# 81.30488828225921

# %%
print( "{0:.0%}".format((mobile+tablet)/total))
# Out:
# 81%

# %%
textfile=open("questiononeGC.txt","w")
textfile.write(("The percentage of people visiting the page via a mobile phone or a tablet device:" "{0:.0%}".format((mobile+tablet)/total)))
textfile.close()
